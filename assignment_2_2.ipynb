# %% [markdown]
# <a href="https://colab.research.google.com/github/JawadArnob/Simulation-and-Modeling-laboratory/blob/main/assignment_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random
import matplotlib.pyplot as plt

N=10000
hit=0

plt.figure(figsize=(8,4))
plt.plot([0,4,4,0,0],[0,0,2,2,0],c='red')

interval=1/1000
ax = []
ay = []

ax1 = []
ay1 = []

ax2 = []
ay2 = []

ax3 = []
ay3 = []


for i in range(0000, 1001):
    x = i*interval
    ax1.append(x)
    y = x
    ay1.append(y)

for i in range(1000, 3001):
    x = i*interval
    ax2.append(x)
    y = 1
    ay2.append(y)

for i in range(3000, 4001):
    x = i*interval
    ax3.append(x)
    y = -x+4
    ay3.append(y)

for i in range(1000, 3001):
    x = i*interval
    ax.append(x)
    y = 1+math.sqrt(1-(x-2)*(x-2))
    ay.append(y)

#plotting shape

plt.plot(ax,ay,c='blue')
plt.plot(ax1,ay1,c='blue')
plt.plot(ax2,ay2,c='blue')
plt.plot(ax3,ay3,c='blue')

hx = []
hy = []

mx = []
my = []

# for i in range(1,N+1):
#   x=random.uniform(0,4)
#   y=random.uniform(0,2)
#  # if y <= math.sqrt(9-x*x) and y>= -(math.sqrt(9-x*x)):
#   if ((x-2)*(x-2)+(y-1)*(y-1))<=1 or x*y<2:
#         hit += 1
#         hx.append(x)
#         hy.append(y)

#   else:
#         mx.append(x)
#         my.append(y)

for i in range(1,N+1):
  x=random.uniform(0,4)
  y=random.uniform(0,2)

  if x>=0 and x<=1:
    if y<=x:
      hit += 1
      hx.append(x)
      hy.append(y)
    else:
      mx.append(x)
      my.append(y)

  elif x>=3 and x<=4:
    if y<=4-x:
       hit += 1
       hx.append(x)
       hy.append(y)
    else:
       mx.append(x)
       my.append(y)
  elif x>=1 and x<=3:
    if y<=1:
       hit += 1
       hx.append(x)
       hy.append(y)
    else:
      if  ((x-2)*(x-2)+(y-1)*(y-1))<=1:
       hit += 1 
       hx.append(x)
       hy.append(y)   
      else:
       mx.append(x)
       my.append(y)     
  else:
     mx.append(x)
     my.append(y)

print(hit)
area=hit*8/N
print(area)


plt.scatter(hx,hy,c='green')
plt.scatter(mx,my,c='red')
# Out:
# 5705
# 4.564

# %%
# Out:
# 0.0
